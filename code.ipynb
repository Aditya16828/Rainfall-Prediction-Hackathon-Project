# %%
import numpy as np
import pandas as pd
import math

# %%
rainfall = pd.read_csv('./train.csv')
rainfall
# Out:
#      MONTH  YEAR  ANDAMAN & NICOBAR ISLANDS  ARUNACHAL PRADESH  \
# 0      JAN  1901                       49.2                NaN
# 1      FEB  1901                       87.1                NaN
# 2      MAR  1901                       29.2                NaN
# 3      APR  1901                        2.3                NaN
# 4      MAY  1901                      528.8                NaN
# ...    ...   ...                        ...                ...
# 1363   AUG  2014                      321.6              599.6
# 1364   SEP  2014                      412.9              343.0
# 1365   OCT  2014                      402.6               35.1
# 1366   NOV  2014                      201.2               20.1
# 1367   DEC  2014                      100.4               10.2
#
#       ASSAM & MEGHALAYA  BIHAR  CHHATTISGARH  COASTAL ANDHRA PRADESH  \
# 0                  27.1   51.8          48.9                    18.8
# ...
